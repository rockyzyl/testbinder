# %%
import theano

theano.test()
# Out:
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# D:\App\anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# Theano version 1.0.1
# theano is installed in D:\App\anaconda3\lib\site-packages\theano
# NumPy version 1.13.3
# NumPy relaxed strides checking option: True
# NumPy is installed in D:\App\anaconda3\lib\site-packages\numpy
# Python version 3.6.3 |Anaconda custom (32-bit)| (default, Oct 15 2017, 07:29:16) [MSC v.1900 32 bit (Intel)]
# nose version 1.3.7
# EE...........E..S......D:\App\anaconda3\lib\site-packages\theano\compile\nanguardmode.py:150: RuntimeWarning: All-NaN slice encountered
#   return np.isinf(np.nanmax(arr)) or np.isinf(np.nanmin(arr))
# D:\App\anaconda3\lib\site-packages\theano\compile\nanguardmode.py:150: RuntimeWarning: All-NaN axis encountered
#   return np.isinf(np.nanmax(arr)) or np.isinf(np.nanmin(arr))
# .E...................................................SSSSSSSSS...SSS..........S.......E..S............................................S.............................................E........SS.S........S.ED:\App\anaconda3\lib\site-packages\theano\gof\vm.py:889: UserWarning: LoopGC does not support partial evaluation, using Stack VM.
#   'LoopGC does not support partial evaluation, '
# SS...SEEEESEEEEEEEESEEEES.D:\App\anaconda3\lib\site-packages\theano\gpuarray\type.py:861: UserWarning: config.experimental.unpickle_gpu_on_cpu is set to True. Unpickling GpuArray as numpy.ndarray
#   "config.experimental.unpickle_gpu_on_cpu is set to True. "
# .EEEEEES.....SEE...D:\App\anaconda3\lib\site-packages\theano\sandbox\rng_mrg.py:1031: UserWarning: MRG_RandomStreams.multinomial_wo_replacement() is deprecated and will be removed in the next release of Theano. Please use MRG_RandomStreams.choice() instead.
#   warnings.warn('MRG_RandomStreams.multinomial_wo_replacement() is '
# ....EES....E..S.E.......EEEE.EEEEEEEEEEEEEEE.EEEE.....EEEEE...E....E.....S.....EEEEEEEEE......EEE......EEEE..........SEE..SSSS.......S.....E...
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\compile\tests\test_builders.py", line 17, in <module>
#     from theano.tests import unittest_tools
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\compile\tests\test_debugmode.py", line 15, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\compile\tests\test_function_module.py", line 16, in <module>
#     from theano.tests.unittest_tools import SkipTest
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\compile\tests\test_ops.py", line 8, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gof\tests\test_destroyhandler.py", line 14, in <module>
#     from theano.tests.unittest_tools import assertFailure_fast
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gof\tests\test_params_type.py", line 11, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: theano.gof.tests.test_vm.test_partial_function
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\case.py", line 197, in runTest
#     self.test(*self.arg)
#   File "D:\App\anaconda3\lib\site-packages\theano\gof\tests\test_vm.py", line 197, in test_partial_function
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_abstractconv.py", line 8, in <module>
#     from theano.tensor.nnet.tests import test_abstract_conv
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\nnet\tests\test_abstract_conv.py", line 11, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_basic_ops.py", line 14, in <module>
#     from theano.tensor.tests import test_basic
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\tests\test_basic.py", line 58, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_blas.py", line 10, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_blocksparse.py", line 6, in <module>
#     import theano.tests.unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_ctc.py", line 8, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_dnn.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_elemwise.py", line 10, in <module>
#     from theano.tests.unittest_tools import SkipTest, assert_allclose
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_extra_ops.py", line 10, in <module>
#     import theano.tensor.tests.test_extra_ops
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\tests\test_extra_ops.py", line 6, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_fft.py", line 7, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_gemmcorr.py", line 7, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_gemmcorr3d.py", line 7, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_linalg.py", line 18, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_multinomial.py", line 15, in <module>
#     import theano.tests.unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_neighbours.py", line 2, in <module>
#     from theano.tensor.nnet.tests import test_neighbours
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\nnet\tests\test_neighbours.py", line 10, in <module>
#     from theano.tests import unittest_tools
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_nnet.py", line 8, in <module>
#     import theano.tests.unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_opt.py", line 9, in <module>
#     from theano.tests import unittest_tools as utt, test_ifelse
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_pool.py", line 13, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_reduction.py", line 7, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_rng_mrg.py", line 10, in <module>
#     from theano.sandbox.tests.test_rng_mrg import java_samples, rng_mrg_overflow
#   File "D:\App\anaconda3\lib\site-packages\theano\sandbox\tests\test_rng_mrg.py", line 15, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_scan.py", line 8, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\gpuarray\tests\test_sort.py", line 4, in <module>
#     import theano.tensor.tests.test_sort
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\tests\test_sort.py", line 5, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
# ...
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\tests\test_var.py", line 7, in <module>
#     import theano.tests.unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\tests\test_xlogx.py", line 8, in <module>
#     from . import test_basic as TT
#   File "D:\App\anaconda3\lib\site-packages\theano\tensor\tests\test_basic.py", line 58, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\typed_list\tests\test_basic.py", line 16, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\typed_list\tests\test_type.py", line 10, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\diverse_tests.py", line 8, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\test_2nd_order_grads.py", line 6, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\test_breakpoint.py", line 5, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\test_gradient.py", line 14, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\test_ifelse.py", line 15, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ======================================================================
# ERROR: Failure: ModuleNotFoundError (No module named 'parameterized')
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "D:\App\anaconda3\lib\site-packages\nose\failure.py", line 39, in runTest
#     raise self.exc_val.with_traceback(self.tb)
#   File "D:\App\anaconda3\lib\site-packages\nose\loader.py", line 417, in loadTestsFromName
#     addr.filename, addr.module)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 47, in importFromPath
#     return self.importFromDir(dir_path, fqname)
#   File "D:\App\anaconda3\lib\site-packages\nose\importer.py", line 94, in importFromDir
#     mod = load_module(part_fqname, fh, filename, desc)
#   File "D:\App\anaconda3\lib\imp.py", line 235, in load_module
#     return load_source(name, filename, file)
#   File "D:\App\anaconda3\lib\imp.py", line 172, in load_source
#     module = _load(spec)
#   File "<frozen importlib._bootstrap>", line 684, in _load
#   File "<frozen importlib._bootstrap>", line 665, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 678, in exec_module
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\test_rop.py", line 15, in <module>
#     from theano.tests import unittest_tools as utt
#   File "D:\App\anaconda3\lib\site-packages\theano\tests\unittest_tools.py", line 7, in <module>
#     from parameterized import parameterized
# ModuleNotFoundError: No module named 'parameterized'
#
# ----------------------------------------------------------------------
# Ran 415 tests in 55.239s
#
# FAILED (SKIP=37, errors=84)
# <nose.result.TextTestResult run=415 errors=84 failures=0>

# %%
import keras

# %%
import numpy
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.cross_validation import cross_val_score
from sklearn.cross_validation import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
# Out:
# D:\App\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Create first network with Keras
from keras.models import Sequential
from keras.layers import Dense
import numpy
# fix random seed for reproducibility
seed = 7
numpy.random.seed(seed)
# load pima indians dataset
dataset = numpy.loadtxt("pima-indians-diabetes.csv", delimiter=",")
# split into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]
# create model
model = Sequential()
model.add(Dense(12, input_dim=8, init='uniform', activation='relu')) 
model.add(Dense(8, init='uniform', activation='relu'))
model.add(Dense(1, init='uniform', activation='sigmoid'))
# Compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) # Fit the model
model.fit(X, Y, nb_epoch=2, batch_size=10)
# evaluate the model
scores = model.evaluate(X, Y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# Using Theano backend.
# WARNING (theano.configdefaults): g++ not available, if using conda: `conda install m2w64-toolchain`
# D:\App\anaconda3\lib\site-packages\theano\configdefaults.py:560: UserWarning: DeprecationWarning: there is no c++ compiler.This is deprecated and with Theano 0.11 a c++ compiler will be mandatory
#   warnings.warn("DeprecationWarning: there is no c++ compiler."
# WARNING (theano.configdefaults): g++ not detected ! Theano will be unable to execute optimized C-implementations (for both CPU and GPU) and will default to Python implementations. Performance will be severely degraded. To remove this warning, set Theano flags cxx to an empty string.
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.
# D:\App\anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(12, input_dim=8, activation="relu", kernel_initializer="uniform")`
#   from ipykernel import kernelapp as app
# D:\App\anaconda3\lib\site-packages\ipykernel_launcher.py:16: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(8, activation="relu", kernel_initializer="uniform")`
#   app.launch_new_instance()
# D:\App\anaconda3\lib\site-packages\ipykernel_launcher.py:17: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, activation="sigmoid", kernel_initializer="uniform")`
# D:\App\anaconda3\lib\site-packages\keras\models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/5
# 768/768 [==============================] - 5s 6ms/step - loss: 0.6787 - acc: 0.6510
# Epoch 2/5
# 768/768 [==============================] - 5s 6ms/step - loss: 0.6617 - acc: 0.6510
# Epoch 3/5
# 768/768 [==============================] - 5s 6ms/step - loss: 0.6538 - acc: 0.6510
# Epoch 4/5
# 768/768 [==============================] - 5s 6ms/step - loss: 0.6490 - acc: 0.6510
# Epoch 5/5
# 768/768 [==============================] - 5s 6ms/step - loss: 0.6394 - acc: 0.6589
# 768/768 [==============================] - 1s 1ms/step
# acc: 66.80%

# %%
import graphviz
